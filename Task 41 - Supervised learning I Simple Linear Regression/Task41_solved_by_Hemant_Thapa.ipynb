# %% [markdown]
# # Supervised Learning I

# %% [markdown]
# ### Hemant Thapa

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = load_diabetes(as_frame=True).data[['s1', 's2']]

# %%
df
# Out:
#            s1        s2
# 0   -0.044223 -0.034821
# 1   -0.008449 -0.019163
# 2   -0.045599 -0.034194
# 3    0.012191  0.024991
# 4    0.003935  0.015596
# ..        ...       ...
# 437 -0.005697 -0.002566
# 438  0.049341  0.079165
# 439 -0.037344 -0.013840
# 440  0.016318  0.015283
# 441  0.083740  0.027809
#
# [442 rows x 2 columns]

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='s1', y='s2', color='red')
plt.show()
plt.close()

# %%
model = LinearRegression()

# %%
X = df['s1'].values.reshape(-1,1)

# %%
y = df['s2'].values

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='s1', y='s2', color='black')
plt.plot(X, y_pred, color='red',linestyle='--')
plt.show()
plt.close()

# %% [markdown]
# #### Compulsory Task1

# %% [markdown]
# 1. Importing dataset

# %%
df = pd.read_csv('insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# 2. Inspecting columns

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# 3. Inspecting Row and Columns

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# 4. Inspecting null values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# We don't have any missing values

# %% [markdown]
# #### 1. Plotting a scatter plot with age on the x-axis and charges on the y-axis.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x = df['age'], y=df['charges'], color='royalblue')
plt.title('Age vs Insurance Cost')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()
plt.close()

# %% [markdown]
# #### 2. Using linear_model.LinearRegression() from sklearn, fit a model to data, and making predictions on data.

# %%
#X is age
X = df['age'].values.reshape(-1,1)
#y is charges
y = df['charges']

# %% [markdown]
# To allow compatibility, we must ensure that our model inputs are of shape (n_samples, n_features). Because there is only one feature, it will be (n_samples, 1):

# %%
#Training model
model.fit(X,y)
# Out:
# LinearRegression()

# %%
#Predicting value
y_pred = model.predict(X)

# %% [markdown]
# #### 3. Plotting another scatter plot with the best-fit line.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x=df['age'], y=df['charges'], color='black')
plt.plot(X, y_pred, color='red')
plt.show()
plt.close()

# %% [markdown]
# #### 4.  Now repeat the above using the data in the relevant columns to determine how BMI affects insurance costs.

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# #### Plotting scatter graph

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x=df['bmi'],y = df['charges'], color='royalblue')
plt.title('Charges vs Bmi')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()
plt.close()

# %% [markdown]
# Declaring X and y

# %%
#X represent bmi
X = df['bmi'].values.reshape(-1,1)
#y represent charges
y = df['charges']

# %%
#Training Linear Model
model.fit(X,y)
# Out:
# LinearRegression()

# %%
#Predicting value
y_pred = model.predict(X)

# %% [markdown]
# #### Plotting best fit line on scatter plot

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x=df['bmi'], y=df['charges'], color='black')
plt.plot(X, y_pred, color='red')
plt.show()
plt.close()
